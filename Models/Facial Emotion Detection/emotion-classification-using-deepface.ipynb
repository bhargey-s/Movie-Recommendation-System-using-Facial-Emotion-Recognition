# %%
import cv2
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('./Images/happy.jpg')
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
predictions = DeepFace.analyze(img1)
predictions
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.77it/s]
# [{'emotion': {'angry': 0.1123364781960845,
#    'disgust': 0.00013021287941228366,
#    'fear': 76.26840472221375,
#    'happy': 20.783601701259613,
#    'sad': 2.634453773498535,
#    'surprise': 0.00028298175038798945,
#    'neutral': 0.2007948700338602},
#   'dominant_emotion': 'fear',
#   'region': {'x': 137, 'y': 47, 'w': 194, 'h': 194},
#   'age': 40,
#   'gender': {'Woman': 5.759339779615402, 'Man': 94.24065947532654},
#   'dominant_gender': 'Man',
#   'race': {'asian': 10.792670398950577,
#    'indian': 15.018756687641144,
#    'black': 3.200221434235573,
#    'white': 16.07469469308853,
#    'middle eastern': 9.757744520902634,
#    'latino hispanic': 45.15590965747833},
#   'dominant_race': 'latino hispanic'}]

# %%
img2 = cv2.imread('./Images/angry.jpeg')
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
predictions = DeepFace.analyze(img2)
predictions[0]['dominant_emotion']
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.73it/s]
# 'angry'

# %%
img3 = cv2.imread('./Images/neutral.jpg')
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
predictions = DeepFace.analyze(img3)
predictions[0]['dominant_emotion']
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.88it/s]
# 'neutral'

# %%
img4 = cv2.imread('./Images/disgusted.jpg')
plt.imshow(cv2.cvtColor(img4, cv2.COLOR_BGR2RGB))
predictions = DeepFace.analyze(img4)
predictions[0]['dominant_emotion']
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.42it/s]
# 'sad'

# %%
img5 = cv2.imread('./Images/surprised.jpg')
plt.imshow(cv2.cvtColor(img5, cv2.COLOR_BGR2RGB))
predictions = DeepFace.analyze(img5)
predictions[0]['dominant_emotion']
# Out:
# Action: race: 100%|██████████| 4/4 [00:08<00:00,  2.05s/it]
# 'fear'

# %%
img6 = cv2.imread('./Images/sad.jpg')
plt.imshow(cv2.cvtColor(img6, cv2.COLOR_BGR2RGB))
predictions = DeepFace.analyze(img6)
predictions[0]['dominant_emotion']
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  3.17it/s]
# 'neutral'
